# %%
# import library
import numpy as np

# %%
class Logistic_Regression():

  # declare learning rate & no. of iterations
  def __init__(self, learning_rate, no_of_iterations):
    self.learning_rate = learning_rate
    self.no_of_iterations = no_of_iterations

  # fit function to train model
  def fit(self, X, Y):
    # no. of data points in dataset (No. of rows) = m
    # no. of input features in dataset (No. of cols) = n
    self.m, self.n = X.shape

    # initiation weight & bias value
    self.w =np.zeros(self.n)
    self.b = 0
    self.X = X
    self.Y = Y

    # implementing Gradient Descent for Optimization
    for i in range(self.no_of_iterations):
      self.update_weights()

  def update_weights(self):
    # Y_hat formula (sigmoid function)
    Y_hat = 1/(1 + np.exp(- (self.X.dot (self.w) + self.b)))

    #derivaties
    dw = (1/self.m)*np.dot(self.X.T, (Y_hat - self.Y))
    db = (1/self.m)*np.sum(Y_hat - self.Y)

    #updating weights & bias using gradient descent
    self.w = self.w - self.learning_rate * dw
    self.b = self.b - self.learning_rate * db

  # Sigmoid Equation & decision boundary
  def predict(self, X):
    Y_pred = 1 / (1 + np.exp( - (X.dot(self.w) + self.b)))
    Y_pred = np.where(Y_pred > 0.5, 1, 0)
    return Y_pred

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis
#
# PIMA Diabetes Dataset

# %%
# load dataset
diabetes_dataset = pd.read_csv("/content/diabetes.csv")

# %%
# print first 5 rows
diabetes_dataset.head()
# Out:
#    Index  Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome  Outcome.1
# 0    0.0            6      148             72  ...                     0.627   50        1        1.0
# 1    1.0            1       85             66  ...                     0.351   31        0       -1.0
# 2    2.0            8      183             64  ...                     0.672   32        1        1.0
# 3    3.0            1       89             66  ...                     0.167   21        0       -1.0
# 4    4.0            0      137             40  ...                     2.288   33        1        1.0
#
# [5 rows x 11 columns]

# %%
# no. of rows & columns
diabetes_dataset.shape
# Out:
# (768, 11)

# %%
# get statistical measures
diabetes_dataset.describe()
# Out:
#           Index  Pregnancies     Glucose  ...         Age     Outcome  Outcome.1
# count  10.00000   768.000000  768.000000  ...  768.000000  768.000000  27.000000
# mean    4.50000     3.845052  120.894531  ...   33.240885    0.348958   0.333333
# std     3.02765     3.369578   31.972618  ...   11.760232    0.476951   0.960769
# min     0.00000     0.000000    0.000000  ...   21.000000    0.000000  -1.000000
# 25%     2.25000     1.000000   99.000000  ...   24.000000    0.000000  -1.000000
# 50%     4.50000     3.000000  117.000000  ...   29.000000    0.000000   1.000000
# 75%     6.75000     6.000000  140.250000  ...   41.000000    1.000000   1.000000
# max     9.00000    17.000000  199.000000  ...   81.000000    1.000000   1.000000
#
# [8 rows x 11 columns]

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#             Index  Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age  Outcome.1
# Outcome                                     ...
# 0        4.000000     3.298000  109.980000  ...                  0.429734  31.190000       -1.0
# 1        4.833333     4.865672  141.257463  ...                  0.550500  37.067164        1.0
#
# [2 rows x 10 columns]

# %%
# separate data & labels
features = diabetes_dataset.drop(columns= 'Outcome', axis=1)
target = diabetes_dataset['Outcome']

# %%
print(features)
# Out:
#      Index  Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age  Outcome.1
# 0      0.0            6      148             72  ...  33.6                     0.627   50        1.0
# 1      1.0            1       85             66  ...  26.6                     0.351   31       -1.0
# 2      2.0            8      183             64  ...  23.3                     0.672   32        1.0
# 3      3.0            1       89             66  ...  28.1                     0.167   21       -1.0
# 4      4.0            0      137             40  ...  43.1                     2.288   33        1.0
# ..     ...          ...      ...            ...  ...   ...                       ...  ...        ...
# 763    NaN           10      101             76  ...  32.9                     0.171   63        NaN
# 764    NaN            2      122             70  ...  36.8                     0.340   27        NaN
# 765    NaN            5      121             72  ...  26.2                     0.245   30        NaN
# 766    NaN            1      126             60  ...  30.1                     0.349   47        NaN
# 767    NaN            1       93             70  ...  30.4                     0.315   23        NaN
#
# [768 rows x 10 columns]

# %%
print(target)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(features)

# %%
print(standardized_data)
# Out:
# [[-1.5666989   0.63994726  0.84832379 ...  0.46849198  1.4259954
#    0.70710678]
#  [-1.21854359 -0.84488505 -1.12339636 ... -0.36506078 -0.19067191
#   -1.41421356]
#  [-0.87038828  1.23388019  1.94372388 ...  0.60439732 -0.10558415
#    0.70710678]
#  ...
#  [        nan  0.3429808   0.00330087 ... -0.68519336 -0.27575966
#           nan]
#  [        nan -0.84488505  0.1597866  ... -0.37110101  1.17073215
#           nan]
#  [        nan -0.84488505 -0.8730192  ... -0.47378505 -0.87137393
#           nan]]

# %%
features = standardized_data
target = diabetes_dataset['Outcome']

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.2, random_state=2)

# %%
print(features.shape, X_train.shape, X_test.shape)
# Out:
# (768, 10) (614, 10) (154, 10)

# %% [markdown]
# Training model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
classifier = Logistic_Regression(learning_rate=0.01, no_of_iterations=1000)

# %%
classifier.fit(X_train, Y_train)

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
# accuracy score on training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy= accuracy_score(Y_train, X_train_prediction)

# %%
print("Accuracy score of train data:", training_data_accuracy)
# Out:
# Accuracy score of train data: 0.6368078175895765

# %%
# accuracy score on test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy= accuracy_score(Y_test, X_test_prediction)

# %%
print("Accuracy score of test data:", test_data_accuracy)
# Out:
# Accuracy score of test data: 0.7077922077922078
